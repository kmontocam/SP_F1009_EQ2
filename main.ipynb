# %%
import matplotlib.pyplot as plt
import sounddevice as sd
import pandas as pd
import numpy as np
from load_database import load_database
# %matplotlib inline
plt.rcParams['figure.figsize']=[10, 6]
plt.rcParams.update({'font.size':14})

# %%
db = pd.read_csv(r'fingerprints.csv')

# Load database with song's fingerprints.
# Database is created by file "create_database.py"

# %%
FingerprintLibrary = load_database(db)

# %%
plt.scatter(FingerprintLibrary['PistaBichota'][0], FingerprintLibrary['PistaBichota'][1])
plt.show()
